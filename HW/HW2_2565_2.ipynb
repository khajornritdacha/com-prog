# %% [markdown]
# # HW2_Selection_Loop: การบ้านครั้งที่ 2 เรื่อง Selection Loop
#
# ##**จุดมุ่งหมายของการบ้าน**
# 1. เข้าใจและใช้งาน `if, if-else, if-elif-else, for, while` ได้
# 2. สร้างความคุ้นเคยกับการบันทึก ดาวน์โหลด และส่งการบ้าน
# 3. เห็นความแตกต่างของการบ้านและ Grader
# 4. ฝึกการปฏิบัติตามความต้องการของโปรแกรม
#
# ##**เริ่มต้น**
# 1. ให้ copy file ไปที่ Doogle Drive ของนิสิตโดยเลือกเมนู File->Save a copy in Drive
# 2. ไปที่ไฟล์ที่ copy มาแล้วตั้งชื่อไฟล์เป็น HW2_XXXXXXXXXX.ipynb เมื่อ XXXXXXXXXX คือรหัสนิสิต
#
# ## <font color=red>สำคัญ: อ่านตรงนี้ด้วย
# ## ข้อห้าม</font>
#  - ห้าม import ใด ๆ
#  - ในฟังก์ชันต้องไม่ใช้ตัวแปรนอกฟังก์ชัน
#  - ห้ามเปลี่ยนบรรทัด `def` ของฟังก์ชันที่ให้เขียน
#  - ในกรณีที่ฟังก์ชันมีการคืนค่า ฟังก์ชันต้องคืนข้อมูลและประเภทข้อมูลตามที่กำหนดเท่านั้น
#  - บรรทัดแรกของ code cell ที่เขียนต้องขึ้นต้นด้วย `# HW02_Selection_Loop` ตามที่ให้ไป ห้ามแก้ไขหรือเพิ่มอะไรเข้าไปก่อนหน้า
#
# - <font color=red>ส่อทุจริต</font> เช่น
#  - ส่งโปรแกรมที่ผู้ส่งไม่สามารถอธิบายได้ว่า ใช้หลักการและทำงานอย่างไร
#   - หรือ ส่งโปรแกรมที่คล้ายกับโปรแกรมของผู้อื่นมาก ๆ (ไม่ว่าจะเป็นผู้ให้หรือผู้รับ จะตั้งใจหรือไม่ก็ตาม)
#   - ฉะนั้น
#     - ให้แน่ใจว่า ไม่ดูโปรแกรมของคนอื่น
#     - ให้แน่ใจว่า ไม่ได้ให้คนอื่นดูโปรแกรมของตัวเอง
#
# - หากพบว่า งานที่ส่งส่อทุจริต จะได้นิสิตจะได้ $0$ ใน<font color=red>การบ้านครั้งนี้ และการบ้านครั้งที่แล้ว ๆ</font>
# - จะตรวจให้คะแนน เมื่อ
#  - แฟ้มที่ส่งครั้งหลังสุดใน MyCourseVille เป็นแฟ้มที่ตั้งชื่อตามที่กำหนด และเป็นแฟ้มที่ได้จากการ File->Download->Download .ipynb เท่านั้น (ไม่ใช่แฟ้ม .py แล้วมา rename เป็น .ipynb)
#  - ฟังก์ชันที่เขียนส่งต้องอยู่ใน code cell ที่ให้มาเท่านั้น
#  - ไม่ทำในสิ่งที่ห้ามทำในข้อห้าม
#  - code cell ที่ให้เขียนสามารถทำงานได้ (ไม่มี error)
#  - ให้แน่ใจว่า code ที่ส่งมา ไม่มี syntax error, indentation error หรืออื่น ๆ ที่ทำให้สั่งทำงาน code ไม่ได้ (ถ้ามี ก็ตรวจไม่ได้ ได้ 0)
#
# ##**การส่งงาน**
# 1. ส่งไฟล์ในรูปแบบ .ipynb ที่ได้จากการเลือกเมนู File->Download->Download .ipynb ของ Colab และส่งแฟ้ม ipynb นี้ใน MyCourseVille
# 2. ตั้งชื่อไฟล์เป็น HW2_XXXXXXXXX.ipynb เมื่อ XXXXXXXXXX คือ รหัสนิสิต
# 3. ส่งแฟ้ม .ipynb กี่ครั้งก็ได้ แต่จะตรวจแฟ้ม .ipynb **แฟ้มล่าสุด ที่ส่งภายในกำหนด** เท่านั้น
# 4. <font color="blue">**กำหนดส่ง คือ ก่อน 23:59 น. ของพุธที่ 15 กุมภาพันธ์ 2566**</font>

# %% [markdown]
# <table>
# <tr>
# <td>
#     <img src=https://upload.wikimedia.org/wikipedia/commons/thumb/1/19/Riemann_sum_%28leftbox%29.gif/240px-Riemann_sum_%28leftbox%29.gif>
# </td>
# <td>
#     <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/6/61/Riemann_sum_%28rightbox%29.gif/240px-Riemann_sum_%28rightbox%29.gif">
# </td>
# <td>
#     <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Riemann_sum_%28middlebox%29.gif/240px-Riemann_sum_%28middlebox%29.gif">
# </td>
# </tr>
# </table>

# %% [markdown]
# # Riemann Sum
#
# การหาพื้นที่ใต้กราฟของฟังก์ชัน $y = f(x)$
#
# โดยปกติเราสามารถหาพื้นที่ใต้กราฟของฟังก์ชัน y = f(x) ช่วง x มีค่าจาก a ถึง b ได้จากการทำอินทิเกรด
#
# \begin{align}
#   \text{พื้นที่ใต้กราฟ}\, = &\int_a^b f(x)\, \mathrm{d}x
# \end{align}
#
# แต่ในการเขียนโปรแกรมไม่มีฟังก์ชันในการทำอินทิเกรด เราก็จะนำความรู้ในวิชาแคลคูลัสมาใช้ในการหาค่าโดยประมาณของอินทิเกรดโดยใช้ Riemann sum ([ดูรายละเอียด Riemann sum เพิ่มเติมได้ที่ wikipedia](https://en.wikipedia.org/wiki/Riemann_sum)) ซึ่งจะแบ่ง $[a, b]$ ออกเป็น $n$ ช่วงเท่าๆ กัน ก็จะได้สมการดังข้างล่าง
#
# \begin{align}
#   \int_a^b f(x)\, \mathrm{d}x\, = \lim_{\Delta{x} \to 0}\, \sum_{i = 1}^{n}\, f(x^*_i)\, \Delta{x}
# \end{align}
#
# โดยที่ $\Delta{x}\, = \dfrac{b - a}{n} \, และ \, {x^*_i} \in \left[{x_{i-1}}, {x_n}\right]$
#
# ดังนั้นจุดต่างๆ ในช่วงที่เราแบ่งออกมาก็จะเป็น $ a,\; a+\Delta x,\;a+2\Delta x,\;\ldots ,\;a+(n-2)\Delta x,\;a+(n-1)\Delta x,\;b $
#
# ---
#
# ## Riemann summation functions
#
# ### 1. Left rule
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c9/LeftRiemann2.svg/440px-LeftRiemann2.svg.png" width="200">
#
#  ค่า $f(x)$ จะหามาจากจุดทางซ้ายของช่วง
#
#  $S_{\mathrm {left} }=\Delta x\left[f(a)+f(a+\Delta x)+f(a+2\Delta x)+\dots +f(b-\Delta x)\right]$
#
#
# ---
#
# ### 2. Right rule
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/45/RightRiemann2.svg/440px-RightRiemann2.svg.png" width="200">
#
# ค่า $f(x)$ จะหามาจากจุดทางขวาของช่วง
#
#  $S_{\mathrm {right} }=\Delta x\left[f(a+\Delta x)+f(a+2\Delta x)+\dots +f(b)\right]$
#
# ---
# ### 3. Midpoint rule
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/d/d2/MidRiemann2.svg/440px-MidRiemann2.svg.png" width="200">
#
# ค่า $f(x)$ จะหามาจากจุดกึ่งกลางของแต่ละช่วง
#
# $S_{\mathrm {mid} }=\Delta x\left[f\left(a+{\tfrac {\Delta x}{2}}\right)+f\left(a+{\tfrac {3\Delta x}{2}}\right)+\dots +f\left(b-{\tfrac {\Delta x}{2}}\right)\right]$
#
# ---
# ### 4. Trapezoid rule
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/7/76/TrapRiemann2.svg/440px-TrapRiemann2.svg.png" width="200">
#
# จะคำนวณพื้นที่ของส่วนรูปสี่เหลี่ยมคางหมูย่อยๆ แต่ละช่วง ด้วยสูตรการหาพื้นที่สี่เหลื่ยมคางหมู $\frac{1}{2}h(b_1+b_2)$ เมื่อ $h$ คือฐาน $b_1, b_2$ คือความยาวของด้านคู่ขนาน
#
# $S_{\mathrm {trap} }={\tfrac {1}{2}}\Delta x\left[f(a)+2f(a+\Delta x)+2f(a+2\Delta x)+\dots +f(b)\right]$
#
# ---
#
# ##**งานของนิสิต**
# เขียนฟังก์ชันต่อไปนี้ให้สมบูรณ์ (คะแนนเต็ม 30 คะแนน)
#
# 1. `riemann_left(f, a, b, n)` คืนค่า Riemann sum ตาม Left rule (5 คะแนน)
#
# 2. `riemann_right(f, a, b, n)` คืนค่า Riemann sum ตาม Right rule (5 คะแนน)
#
# 3. `riemann_mid(f, a, b, n)` คืนค่า Riemann sum ตาม Midpoint rule (5 คะแนน)
#
# 4. `riemann_trap(f, a, b, n)` คืนค่า Riemann sum ตาม Trapezoid rule (5 คะแนน)
#
# 5. `estimate(riemann_sum_function, f, a, b, precision)`  (10 คะแนน)
#  - `riemann_sum_function` เป็นฟังก์ชัน `riemann_left, riemann_right, riemann_mid, หรือ riemann_trap`
#  - `f` เป็นฟังก์ชันที่ต้องการจะหาค่า Riemann sum
#  - `a, b` คือช่วง `[a, b]` ที่กำหนดขอบเขตของการหา Riemann sum
#  - precision เป็นจำนวนเต็มที่กำหนดความแม่นยำถึงทศนิยมกี่ตำแหน่ง (ในการตรวจ จะตรวจไม่เกินทศนิยมตำแหน่งที่ 7)
#
#  คืนค่าเป็นลิสต์ที่ประกอบด้วย
#  - ค่าที่ประมาณของ Riemann sum ที่ใช้วิธีตาม riemann_sum_function ที่ส่งมา (ที่มีความแม่นยำตามที่ต้องการ)
#  - จำนวนช่วงน้อยที่สุดที่ใช้แบ่งเพื่อให้ได้ความแม่นยำตามที่ต้องการ (ซึ่งคือจำนวนเต็มบวกน้อยสุด k ที่ทำให้ค่าทีประมาณได้จากการแบ่งเป็น `k` ช่วงและแบ่งเป็น `k+1` ช่วง มีค่าไม่แตกต่างกันตามความแม่นยำที่ต้องการ)
#
# <!-- ค่า `Riemann sum` หาจาก `riemann_sum_function` ที่ส่งมา โดยใช้ค่า `n` ที่เป็นจำนวนช่วงที่แบ่งเริ่มต้นที่ `n = 10` ช่วง
#  - `round(riemann sum, precision)`,
#  - ค่า `k` โดย k เป็นจำนวนช่วงน้อยที่สุดที่ทำให้ ค่า  riemann sum ที่แบ่งออกเป็น `k` ช่วงและ `k+1` ช่วงมีค่าเท่ากัน (คิดค่าถึงทศนิยมตำแหน่งที่กำหนดโดยค่าของ `precision` โดยใช้ `round(value, precision)` ในการเปรียบเทียบ  -->
#
# ---
#
# ## การเรียกใช้ Riemann sum function
#
# - ถ้าต้องการหา Riemann sum ด้วย Right rule ของฟังก์ชัน `math.sin` จากช่วง `[0, math.pi]` โดยแบ่งเป็นส่วนย่อย 20 ช่วง ก็เขียน <font color="red">`riemann_right(math.sin, 0, math.pi, 20)`</font>
#
# - ถ้าต้องการหา Riemann sum ของฟังก์ชัน `f1` จากช่วง `[2, 4]` โดยแบ่งเป็นส่วนย่อย `n` ช่วง ตาม Trapezoid rule ก็เขียน <font color="red">`riemann_trap(f1, 2, 4, n)`</font>
#
#
# ## การเรียกใช้ `estimate`
# - ถ้าต้องการหาค่าโดยประมาณ Riemann sum ด้วย Midpoint rule ของฟังก์ชัน `math.sin` จากช่วง `[0, math.pi]` โดยคิดความแม่นยำถึงทศนิยมตำแหน่งที่ 4 ก็เขียน <font color="red">`estimate(riemann_mid, math.sin, 0, math.pi, 4)`</font>
#
# ---
# ### [คลิกที่นี่ เพื่อดูตัวอย่างการใช้ตัวแปรเป็นฟังก์ชันและการใช้ส่งฟังก์ชันเป็นพารามิเตอร์ให้กับฟังก์ชันอื่น](https://colab.research.google.com/drive/1sNRsMNfklJptpoLMdTZbuzgjzJUymuSX?usp=sharing)
#
# ### [คลิกที่นี่เพื่อดู vdo อธิบายการบ้านนี้](https://youtu.be/cyaQ35Z4o7o)

# %%
# HW02_Selection_Loop (ไม่ลบหรือแก้ไขบรรทัดนี้ หรือเพิ่มอะไรก่อนบรรทัดนี้ โดยเด็ดขาด)

#-----------------------------
# Riemann sum functions
#-----------------------------
def riemann_left(f, a, b, n):
    length = (b-a)/n
    i = a
    ans = 0
    while i < b:
        ans += f(i)*length
        i += length
    return ans

    # คืนค่าเป็นจำนวนจริงของ Riemann sum โดยใช้ Left rule
    dx = (b-a)/n
    ans = 0.0
    for i in range(n):
        ans += f(a + dx*i)*dx
    return ans

def riemann_right(f, a, b, n):
    # คืนค่าเป็นจำนวนจริงของ Riemann sum โดยใช้ Right rule
    dx = (b-a)/n
    ans = 0
    for i in range(n):
        ans += f(a + dx*(i+1))*dx
    return ans

def riemann_mid(f, a, b, n):
    # คืนค่าเป็นจำนวนจริงของ Riemann sum โดยใช้ Midpoint rule
    dx = (b-a)/n
    ans = 0
    for i in range(n):
        ans += f(a + (2*i+1)*dx/2)*dx
    return ans

def riemann_trap(f, a, b, n):
    # คืนค่าเป็นจำนวนจริงของ Riemann sum โดยใช้ Trapezoid rule
    dx = (b-a)/n
    ans = 0
    for i in range(n):
        ans += f(a + i*dx) + f(a + (i+1)*dx)
    return ans/2*dx

#-----------------------------
def estimate(riemann_sum_function, f, a, b, precision):
    # คืนค่าเป็นลิสต์ที่ประกอบด้วย
    #  - ค่าที่ประมาณ (เป็นจำนวนจริง) ของ Riemann sum ที่ใช้วิธีตาม riemann_sum_function ที่ส่งมา (ที่มีความแม่นยำตามที่ต้องการ)
    #  - จำนวนช่วงน้อยที่สุด (เป็นจำนวนเต็ม) ที่ใช้แบ่งเพื่อให้ได้ความแม่นยำตามที่ต้องการ (คืนค่า k เมื่อค่าทีประมาณได้จากการแบ่งเป็น k ช่วงและแบ่งเป็น k+1 ช่วง มีค่าไม่แตกต่างกันตามความแม่นยำที่ต้องการ)

    # ในฟังก์ชันนี้ จะเรียก riemann_sum_function(f, a, b, n) หลาย ๆ รอบ จนกว่าจะได้คำตอบตามที่กำหนด
    k = 1
    riemann_sum = 0
    while True:
        v1 = riemann_sum_function(f, a, b, k)
        v2 = riemann_sum_function(f, a, b, k+1)
        if (abs(v2-v1) < 10**(-precision)):
            riemann_sum = v1
            break
        k += 1
        

    return [round(riemann_sum, precision), k] # ห้ามลบหรือแก้ไขบรรทัดนี้

# %% [markdown]
# ## กรณีทดสอบ
# ให้ run code cell ก่อนหน้าทุกครั้งก่อนที่จะ run testcase
#
# **<font color="blue">ในการตรวจจะใช้กรณีทดสอบที่แตกต่างกันกับที่ให้</font>**
#
# ผลลัพธ์ที่ควรจะได้สำหรับแต่ละ testcase
#
# ---
# `test_riemann_left_1()`
# ```
# ---riemann_left of math.sin---
# 0.9194031700146124 0.91940317
# 0.992125456605633 0.9921254566
# 0.0 0.0
# -1.0065988485252912e-14 -0.0
# ```
# ---
# `test_riemann_left_2()`
# ```
# ---riemann_left of f1---
# 10.34880000000001 10.3488
# 10.63468800000001 10.634688
# 158.99309999999986 158.9931
# 161.84828100000064 161.848281
# ```
# ---
# `test_riemann_right_1()`
# ```
# ---riemann_right of math.sin---
# 1.076482802694102 1.0764828027
# 1.0078334198735819 1.0078334199
# -1.5389365549774318e-16 -0.0
# -1.0639436810484067e-14 -0.0
# ```
# ---
# `test_riemann_right_2()`
# ```
# ---riemann_right of f1---
# 10.98880000000001 10.9888
# 10.69868800000001 10.698688
# 165.36309999999986 165.3631
# 162.48528100000064 162.485281
# ```
# ---
# `test_riemann_mid_1()`
# ```
# ---riemann_mid of math.sin---
# 1.0010288241427086 1.0010288241
# 1.0000102809119054 1.0000102809
# -1.743934249004316e-16 -0.0
# -1.1318569259600262e-14 -0.0
# ```
# ---
# `test_riemann_mid_2()`
# ```
# ---riemann_mid of f1---
# 10.665600000000008 10.6656
# 10.666656000000016 10.666656
# 162.16094999999981 162.16095
# 162.1666095000004 162.1666095
# ```
# ---
# `test_riemann_trap_1()`
# ```
# ---riemann_trep of math.sin---
# 0.9979429863543572 0.9979429864
# 0.9999794382396074 0.9999794382
# -7.694682774887159e-17 -0.0
# -1.00736831680278e-14 -0.0
# ```
# ---
# `test_riemann_trap_2()`
# ```
# ---riemann_trep of f1---
# 10.668800000000008 10.6688
# 10.66668800000001 10.666688
# 162.17809999999986 162.1781
# 162.16678100000064 162.166781
# ```
# ---
# `test_estimate_1()`
# ```
# ### test estimate of math.sin ###
# ---riemann_left---
# [0.8, 4]
# [0.974, 30]
# [0.99734, 295]
# [0.9997224, 2829]
# ---riemann_right---
# [1.2, 3]
# [1.024, 32]
# [1.00272, 288]
# [1.0002756, 2849]
# ---riemann_mid---
# [1.0, 2]
# [1.002, 7]
# [1.00011, 30]
# [1.0000056, 135]
# ---riemann_trap---
# [1.0, 3]
# [0.997, 8]
# [0.99986, 38]
# [0.9999924, 164]
# ```
# ---
# `test_estimate_2()`
# ```
# ### test estimate of f1 ###
# ---riemann_left---
# [19.13, 42]
# [19.4622, 416]
# [19.49607, 4007]
# ---riemann_right---
# [19.84, 46]
# [19.5381, 413]
# [19.503948, 3989]
# ---riemann_mid---
# [19.48, 7]
# [19.4988, 30]
# [19.499943, 140]
# ---riemann_trap---
# [19.52, 10]
# [19.5016, 37]
# [19.500073, 175]
# ```

# %%
# โปรแกรมที่ต่อจากนี้เป็นส่วนของการทดสอบ
# แนะนำให้ทดสอบทีละ testcase เพราะจะใช้เวลาค่อนข้างนาน ถ้าทดสอบทุก testcase
# run code cell ก่อนหน้านี้ ก่อนที่จะ run testcase
import math

def f1(x):
    return 0.5*(x**2)

def test_riemann_left_1():
    print('---riemann_left of math.sin---')
    x = riemann_left(math.sin, 0, 0.5*math.pi, 10)
    print(x, round(x, 10))
    x = riemann_left(math.sin, 0, 0.5*math.pi, 100)
    print(x, round(x, 10))
    x = riemann_left(math.sin, 0, 2*math.pi, 10)
    print(x, round(x, 10))
    x = riemann_left(math.sin, 0, 2*math.pi, 100)
    print(x, round(x, 10))

def test_riemann_left_2():
    print('---riemann_left of f1---')
    x = riemann_left(f1, 0, 4, 50)
    print(x, round(x, 10))
    x = riemann_left(f1, 0, 4, 500)
    print(x, round(x, 10))
    x = riemann_left(f1, 3, 10, 50)
    print(x, round(x, 10))
    x = riemann_left(f1, 3, 10, 500)
    print(x, round(x, 10))
#-----------------------------------------------------
def test_riemann_right_1():
    print('---riemann_right of math.sin---')
    x = riemann_right(math.sin, 0, 0.5*math.pi, 10)
    print(x, round(x, 10))
    x = riemann_right(math.sin, 0, 0.5*math.pi, 100)
    print(x, round(x, 10))
    x = riemann_right(math.sin, 0, 2*math.pi, 10)
    print(x, round(x, 10))
    x = riemann_right(math.sin, 0, 2*math.pi, 100)
    print(x, round(x, 10))

def test_riemann_right_2():
    print('---riemann_right of f1---')
    x = riemann_right(f1, 0, 4, 50)
    print(x, round(x, 10))
    x = riemann_right(f1, 0, 4, 500)
    print(x, round(x, 10))
    x = riemann_right(f1, 3, 10, 50)
    print(x, round(x, 10))
    x = riemann_right(f1, 3, 10, 500)
    print(x, round(x, 10))
#-----------------------------------------------------
def test_riemann_mid_1():
    print('---riemann_mid of math.sin---')
    x = riemann_mid(math.sin, 0, 0.5*math.pi, 10)
    print(x, round(x, 10))
    x = riemann_mid(math.sin, 0, 0.5*math.pi, 100)
    print(x, round(x, 10))
    x = riemann_mid(math.sin, 0, 2*math.pi, 10)
    print(x, round(x, 10))
    x = riemann_mid(math.sin, 0, 2*math.pi, 100)
    print(x, round(x, 10))

def test_riemann_mid_2():
    print('---riemann_mid of f1---')
    x = riemann_mid(f1, 0, 4, 50)
    print(x, round(x, 10))
    x = riemann_mid(f1, 0, 4, 500)
    print(x, round(x, 10))
    x = riemann_mid(f1, 3, 10, 50)
    print(x, round(x, 10))
    x = riemann_mid(f1, 3, 10, 500)
    print(x, round(x, 10))
#-----------------------------------------------------
def test_riemann_trap_1():
    print('---riemann_trap of math.sin---')
    x = riemann_trap(math.sin, 0, 0.5*math.pi, 10)
    print(x, round(x, 10))
    x = riemann_trap(math.sin, 0, 0.5*math.pi, 100)
    print(x, round(x, 10))
    x = riemann_trap(math.sin, 0, 2*math.pi, 10)
    print(x, round(x, 10))
    x = riemann_trap(math.sin, 0, 2*math.pi, 100)
    print(x, round(x, 10))

def test_riemann_trap_2():
    print('---riemann_trap of f1---')
    x = riemann_trap(f1, 0, 4, 50)
    print(x, round(x, 10))
    x = riemann_trap(f1, 0, 4, 500)
    print(x, round(x, 10))
    x = riemann_trap(f1, 3, 10, 50)
    print(x, round(x, 10))
    x = riemann_trap(f1, 3, 10, 500)
    print(x, round(x, 10))
#-----------------------------------------------------
def test_estimate_1():
    print('### test estimate of math.sin ###')
    print('---riemann_left---')
    for precision in [1, 3, 5, 7]:
        print(estimate(riemann_left, math.sin, 0, 0.5*math.pi, precision))
    print('---riemann_right---')
    for precision in [1, 3, 5, 7]:
        print(estimate(riemann_right, math.sin, 0, 0.5*math.pi, precision))
    print('---riemann_mid---')
    for precision in [1, 3, 5, 7]:
        print(estimate(riemann_mid, math.sin, 0, 0.5*math.pi, precision))
    print('---riemann_trap---')
    for precision in [1, 3, 5, 7]:
        print(estimate(riemann_trap, math.sin, 0, 0.5*math.pi, precision))
#-----------------------------------------------------
def test_estimate_2():
    print('### test estimate of f1 ###')
    print('---riemann_left---')
    for precision in [2, 4, 6]:
        print(estimate(riemann_left, f1, 2, 5, precision))
    print('---riemann_right---')
    for precision in [2, 4, 6]:
        print(estimate(riemann_right, f1, 2, 5, precision))
    print('---riemann_mid---')
    for precision in [2, 4, 6]:
        print(estimate(riemann_mid, f1, 2, 5, precision))
    print('---riemann_trap---')
    for precision in [2, 4, 6]:
        print(estimate(riemann_trap, f1, 2, 5, precision))
#-----------------------------------------------------
# ให้ uncomment testcase เพื่อทดสอบทีละอัน
# ถ้า run testcase ทั้งหมดจะใช้เวลานาน
test_riemann_left_1()
test_riemann_left_2()
# test_riemann_right_1()
# test_riemann_right_2()
# test_riemann_mid_1()
# test_riemann_mid_2()
# test_riemann_trap_1()
# test_riemann_trap_2()
# test_estimate_1()
# test_estimate_2()
# Out:
# ---riemann_left of math.sin---
# 0.9194031700146124 0.91940317
# 1.0078334198735823 1.0078334199
# 0.0 0.0
# -1.1130108038288016e-14 -0.0
# ---riemann_left of f1---
# 10.348800000000004 10.3488
# 10.634688000000013 10.634688
# 158.99309999999983 158.9931
# 162.54828100000066 162.548281
